# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.12/dist-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (3.10.0)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from mlxtend.preprocessing import TransactionEncoder
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
cpu = pd.read_csv("cpu.csv")
gpu = pd.read_csv("gpu.csv")
ram = pd.read_csv("ram.csv")
mobo = pd.read_csv("motherboard.csv")
psu = pd.read_csv("psu.csv")
storage = pd.read_csv("storage.csv")

# %% [markdown]
# cell 1

# %%
cpu["component_type"] = "CPU"
gpu["component_type"] = "GPU"
ram["component_type"] = "RAM"
mobo["component_type"] = "Motherboard"
psu["component_type"] = "PSU"
storage["component_type"] = "Storage"

# %% [markdown]
# cell 2

# %%
print("CPU columns:", cpu.columns.tolist())
print("GPU columns:", gpu.columns.tolist())
print("RAM columns:", ram.columns.tolist())
print("Motherboard columns:", mobo.columns.tolist())
print("PSU columns:", psu.columns.tolist())
print("Storage columns:", storage.columns.tolist())

# %% [markdown]
# **Column Standardization**
#
# The original dataset consists of multiple CSV files representing different PC components. Each file uses slightly different column naming conventions. To ensure consistency and enable unified processing, column names are standardized across all datasets. This step improves readability, avoids ambiguity, and allows common attributes (e.g., brand, socket, wattage) to be analyzed uniformly.

# %%
def standardize_columns(df):
    df = df.rename(columns={
        "Name": "name",
        "Price": "price",
        "Producer": "brand",
        "Socket": "socket",
        "Chipset": "chipset",
        "Ram Type": "ram_type",
        "Memory Type": "memory_type",
        "Form Factor": "form_factor",
        "Size": "capacity",
        "Clock": "clock",
        "Boost Clock": "boost_clock",
        "Base Clock": "base_clock",
        "Watt": "wattage",
        "Efficiency Rating": "efficiency",
        "Vram": "vram",
        "TDP": "tdp",
        "Cores": "cores",
        "Threads": "threads"
    })
    return df

# %% [markdown]
# **Applying Standardized Naming**
#
# The column standardization function is applied to all component datasets. This ensures that similar attributes across different hardware types use the same naming scheme, which is necessary before merging the datasets into a single unified table.

# %%
cpu = standardize_columns(cpu)
gpu = standardize_columns(gpu)
ram = standardize_columns(ram)
mobo = standardize_columns(mobo)
psu = standardize_columns(psu)
storage = standardize_columns(storage)

# %% [markdown]
# **Dataset Unification**
#
# All standardized component datasets are merged into a single dataframe. Each row represents one hardware item, while a new component_type attribute identifies the category of the component. Missing values are expected at this stage because different components naturally have different specifications.

# %%
hardware_df = pd.concat(
    [cpu, gpu, ram, mobo, psu, storage],
    ignore_index=True,
    sort=False
)

hardware_df.head()
# Out:
#                 name        price brand               MPN           EAN  UPC  \
# 0  AMD Ryzen 5 5600X  $158.86 USD   AMD  100-100000065BOX  730143312042  NaN
# 1   AMD Athlon 3000G   $53.22 USD   AMD     YD3000C6FHBOX  730143311731  NaN
# 2  AMD Ryzen 3 3300X  $150.09 USD   AMD  100-100000159BOX  730143312172  NaN
# 3   AMD Ryzen 5 5500   $87.04 USD   AMD  100-100000457BOX  730143314121  NaN
# 4   AMD Ryzen 5 5600  $133.46 USD   AMD  100-100000927BOX  730143314190  NaN
#
#   base_clock Turbo Clock Unlocked Multiplier  cores  threads   tdp socket  \
# 0    3.7 GHz     4.6 GHz                True    6.0     12.0  65 W    AM4
# 1    3.5 GHz         NaN                True    2.0      4.0  35 W    AM4
# 2    3.8 GHz     4.3 GHz                True    4.0      8.0  65 W    AM4
# 3    3.6 GHz     4.2 GHz                True    6.0     12.0  65 W    AM4
# 4    3.5 GHz     4.4 GHz                True    6.0     12.0  65 W    AM4
#
#      Integrated GPU                                       Product Page  \
# 0             False  https://www.amazon.ca/dp/B08166SLDF?tag=pckomb...
# 1  Radeon RX Vega 3  https://www.amazon.ca/dp/B0815JGFQ8?tag=pckomb...
# 2             False  https://www.amazon.ca/dp/B0876YS2T4?tag=pckomb...
# 3             False  https://www.amazon.ca/dp/B09VCJ171S?tag=pckomb...
# 4             False  https://www.amazon.ca/dp/B09VCHR1VH?tag=pckomb...
#
#   component_type Length  Slots  8-Pin Connectors  6-Pin Connectors  HDMI  \
# 0            CPU    NaN    NaN               NaN               NaN   NaN
# 1            CPU    NaN    NaN               NaN               NaN   NaN
# 2            CPU    NaN    NaN               NaN               NaN   NaN
# 3            CPU    NaN    NaN               NaN               NaN   NaN
# 4            CPU    NaN    NaN               NaN               NaN   NaN
#
#    DisplayPort  DVI  VGA boost_clock vram Memory Clock ram_type capacity  \
# 0          NaN  NaN  NaN         NaN  NaN          NaN      NaN      NaN
# 1          NaN  NaN  NaN         NaN  NaN          NaN      NaN      NaN
# 2          NaN  NaN  NaN         NaN  NaN          NaN      NaN      NaN
# 3          NaN  NaN  NaN         NaN  NaN          NaN      NaN      NaN
# 4          NaN  NaN  NaN         NaN  NaN          NaN      NaN      NaN
#
#    clock Timings  Sticks chipset Unlocked form_factor memory_type  \
# 0    NaN     NaN     NaN     NaN      NaN         NaN         NaN
# 1    NaN     NaN     NaN     NaN      NaN         NaN         NaN
# 2    NaN     NaN     NaN     NaN      NaN         NaN         NaN
# 3    NaN     NaN     NaN     NaN      NaN         NaN         NaN
# 4    NaN     NaN     NaN     NaN      NaN         NaN         NaN
#
#   Memory Capacity  RAM Slots SATA  Display Port WiFi Integrated Graphics  \
# 0             NaN        NaN  NaN           NaN  NaN                 NaN
# 1             NaN        NaN  NaN           NaN  NaN                 NaN
# 2             NaN        NaN  NaN           NaN  NaN                 NaN
# 3             NaN        NaN  NaN           NaN  NaN                 NaN
# 4             NaN        NaN  NaN           NaN  NaN                 NaN
#
#   wattage efficiency Protocol NAND Controller
# 0     NaN        NaN      NaN  NaN        NaN
# 1     NaN        NaN      NaN  NaN        NaN
# 2     NaN        NaN      NaN  NaN        NaN
# 3     NaN        NaN      NaN  NaN        NaN
# 4     NaN        NaN      NaN  NaN        NaN

# %% [markdown]
# Initial Dataset Assessment (Before Preprocessing)
#
# This step provides an overview of the unified dataset, including:
#
# *   Total number of records
# *   Total number of attributes
# *   Proportion of missing values
#
# This analysis highlights the sparsity inherent in multi-component hardware data and motivates the preprocessing steps that follow.

# %%
print("Total records:", hardware_df.shape[0])
print("Total attributes:", hardware_df.shape[1])

hardware_df.isnull().mean().sort_values(ascending=False).head(10)
# Out:
# Total records: 6357
# Total attributes: 47
# Controller             0.949190
# Turbo Clock            0.948561
# Unlocked Multiplier    0.948403
# threads                0.948403
# cores                  0.948403
# Integrated GPU         0.948403
# base_clock             0.948403
# NAND                   0.945415
# Protocol               0.928268
# efficiency             0.860941
# dtype: float64

# %% [markdown]
# **Feature Selection for Association Rule Mining**
#
# Only attributes relevant to compatibility and association analysis are selected. Non-informative fields such as product codes, URLs, and identifiers are excluded. This reduces dimensionality, improves algorithm efficiency, and focuses rule generation on meaningful hardware relationships.

# %%
arm_features = [
    "component_type",
    "brand",
    "socket",
    "chipset",
    "ram_type",
    "memory_type",
    "form_factor",
    "capacity",
    "wattage",
    "vram",
    "efficiency"
]

arm_df = hardware_df[arm_features].copy()
arm_df.head()
# Out:
#   component_type brand socket chipset ram_type memory_type form_factor  \
# 0            CPU   AMD    AM4     NaN      NaN         NaN         NaN
# 1            CPU   AMD    AM4     NaN      NaN         NaN         NaN
# 2            CPU   AMD    AM4     NaN      NaN         NaN         NaN
# 3            CPU   AMD    AM4     NaN      NaN         NaN         NaN
# 4            CPU   AMD    AM4     NaN      NaN         NaN         NaN
#
#   capacity wattage vram efficiency
# 0      NaN     NaN  NaN        NaN
# 1      NaN     NaN  NaN        NaN
# 2      NaN     NaN  NaN        NaN
# 3      NaN     NaN  NaN        NaN
# 4      NaN     NaN  NaN        NaN

# %% [markdown]
# **Handling Missing Values**
#
# Since association rule mining requires categorical completeness, missing values are replaced with a neutral placeholder ("Unknown"). This prevents the loss of transactions while preserving the semantic meaning that a specification is not applicable or unavailable for a given component.

# %%
arm_df = arm_df.fillna("Unknown")

# %% [markdown]
# **Preprocessing Impact Evaluation**
#
# This step compares missing value statistics before and after preprocessing. It quantitatively demonstrates the effectiveness of the data cleaning process and provides transparency in data transformation, which is essential for reproducible data mining experiments.

# %%
print("Before preprocessing:")
print("Missing values (%):")
print(hardware_df.isnull().mean().mean() * 100)

print("\nAfter preprocessing:")
print("Missing values (%):")
print(arm_df.isnull().mean().mean() * 100)
# Out:
# Before preprocessing:
# Missing values (%):
# 69.7241104629174
#
# After preprocessing:
# Missing values (%):
# 0.0

# %% [markdown]
# **Transaction Construction**
#
# Each hardware item is converted into a transaction by representing attribute-value pairs as individual items. This transformation allows the originally non-transactional dataset to be used with association rule mining algorithms such as Apriori.

# %%
transactions = arm_df.apply(
    lambda row: [f"{col}={row[col]}" for col in arm_df.columns],
    axis=1
).tolist()

transactions[:2]
# Out:
# [['component_type=CPU',
#   'brand=AMD',
#   'socket=AM4',
#   'chipset=Unknown',
#   'ram_type=Unknown',
#   'memory_type=Unknown',
#   'form_factor=Unknown',
#   'capacity=Unknown',
#   'wattage=Unknown',
#   'vram=Unknown',
#   'efficiency=Unknown'],
#  ['component_type=CPU',
#   'brand=AMD',
#   'socket=AM4',
#   'chipset=Unknown',
#   'ram_type=Unknown',
#   'memory_type=Unknown',
#   'form_factor=Unknown',
#   'capacity=Unknown',
#   'wattage=Unknown',
#   'vram=Unknown',
#   'efficiency=Unknown']]

# %%
from mlxtend.preprocessing import TransactionEncoder

# Assume `transactions` is a list of lists created in preprocessing
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)

encoded_df = pd.DataFrame(te_array, columns=te.columns_)
encoded_df.head()
# Out:
#    brand=ADATA  brand=AMD  brand=ASRock  brand=ASUS  brand=Adata  \
# 0        False       True         False       False        False
# 1        False       True         False       False        False
# 2        False       True         False       False        False
# 3        False       True         False       False        False
# 4        False       True         False       False        False
#
#    brand=Aerocool  brand=Akasa  brand=Antec  brand=Asus  brand=Avexir  \
# 0           False        False        False       False         False
# 1           False        False        False       False         False
# 2           False        False        False       False         False
# 3           False        False        False       False         False
# 4           False        False        False       False         False
#
#    brand=Ballistix  brand=Biostar  brand=BitFenix  brand=Chieftec  \
# 0            False          False           False           False
# 1            False          False           False           False
# 2            False          False           False           False
# 3            False          False           False           False
# 4            False          False           False           False
#
#    brand=Club 3D  brand=Cooler Master  brand=Corsair  brand=Cougar  \
# 0          False                False          False         False
# 1          False                False          False         False
# 2          False                False          False         False
# 3          False                False          False         False
# 4          False                False          False         False
#
#    brand=Crucial  brand=EVGA  brand=Enermax  brand=Fractal Design  \
# 0          False       False          False                 False
# 1          False       False          False                 False
# 2          False       False          False                 False
# 3          False       False          False                 False
# 4          False       False          False                 False
#
#    brand=G. Skill  brand=G.Skill  brand=Gainward  brand=Galax  brand=Gigabyte  \
# 0           False          False           False        False           False
# 1           False          False           False        False           False
# 2           False          False           False        False           False
# 3           False          False           False        False           False
# 4           False          False           False        False           False
#
#    brand=HIS  brand=Hynix  brand=HyperX  brand=IN WIN  brand=INNO3D  \
# 0      False        False         False         False         False
# 1      False        False         False         False         False
# 2      False        False         False         False         False
# 3      False        False         False         False         False
# 4      False        False         False         False         False
#
#    brand=Impactics  brand=InWin  brand=Intel  brand=Intenso  brand=KFA2  \
# 0            False        False        False          False       False
# 1            False        False        False          False       False
# 2            False        False        False          False       False
# 3            False        False        False          False       False
# 4            False        False        False          False       False
#
#    brand=King Kits  brand=Kingston  brand=Kioxia  brand=Kolink  brand=Lian Li  \
# 0            False           False         False         False          False
# 1            False           False         False         False          False
# 2            False           False         False         False          False
# 3            False           False         False         False          False
# 4            False           False         False         False          False
#
#    brand=MSI  brand=Mach Xtreme Technology  brand=Micron  brand=Montech  \
# 0      False                         False         False          False
# 1      False                         False         False          False
# 2      False                         False         False          False
# 3      False                         False         False          False
# 4      False                         False         False          False
#
#    brand=Mushkin  brand=NZXT  brand=OCZ  brand=OWC  brand=PHANTEKS  brand=PNY  \
# 0          False       False      False      False           False      False
# 1          False       False      False      False           False      False
# 2          False       False      False      False           False      False
# 3          False       False      False      False           False      False
# 4          False       False      False      False           False      False
#
#    brand=Palit  brand=Patriot  brand=PowerColor  brand=SAMSUNG  \
# 0        False          False             False          False
# 1        False          False             False          False
# 2        False          False             False          False
# 3        False          False             False          False
# 4        False          False             False          False
#
#    brand=SAPPHIRE  brand=Sabrent  brand=Samsung  brand=SanDisk  \
# 0           False          False          False          False
# 1           False          False          False          False
# 2           False          False          False          False
# 3           False          False          False          False
# 4           False          False          False          False
#
#    brand=Sapphire  brand=Seagate  brand=Seasonic  brand=Silentmaxx  \
# 0           False          False           False             False
# 1           False          False           False             False
# 2           False          False           False             False
# 3           False          False           False             False
# 4           False          False           False             False
#
#    brand=Silverstone  brand=Solidigm  brand=Sparkle  brand=Streacom  \
# 0              False           False          False           False
# 1              False           False          False           False
# 2              False           False          False           False
# 3              False           False          False           False
# 4              False           False          False           False
#
#    brand=Super Flower  brand=Supermicro  brand=Team Group  brand=Thermaltake  \
# 0               False             False             False              False
# 1               False             False             False              False
# 2               False             False             False              False
# 3               False             False             False              False
# 4               False             False             False              False
#
#    brand=Toshiba  brand=Transcend  brand=Western Digital  brand=XFX  \
# 0          False            False                  False      False
# 1          False            False                  False      False
# 2          False            False                  False      False
# 3          False            False                  False      False
# 4          False            False                  False      False
#
#    brand=Xigmatek  brand=Xilence  brand=ZOTAC  brand=Zalman  brand=be quiet!  \
# 0           False          False        False         False            False
# 1           False          False        False         False            False
# 2           False          False        False         False            False
# 3           False          False        False         False            False
# 4           False          False        False         False            False
#
#    capacity=0 GB  capacity=1 GB  capacity=100 GB  capacity=1000 GB  \
# 0          False          False            False             False
# 1          False          False            False             False
# 2          False          False            False             False
# 3          False          False            False             False
# 4          False          False            False             False
#
#    capacity=1024 GB  capacity=118 GB  capacity=12 GB  capacity=120 GB  \
# 0             False            False           False            False
# 1             False            False           False            False
# 2             False            False           False            False
# 3             False            False           False            False
# 4             False            False           False            False
#
#    capacity=128 GB  capacity=16 GB  capacity=180 GB  capacity=192 GB  \
# 0            False           False            False            False
# 1            False           False            False            False
# 2            False           False            False            False
# 3            False           False            False            False
# 4            False           False            False            False
#
#    capacity=1920 GB  capacity=2 GB  capacity=200 GB  capacity=2000 GB  \
# 0             False          False            False             False
# 1             False          False            False             False
# 2             False          False            False             False
# 3             False          False            False             False
# 4             False          False            False             False
#
#    capacity=24 GB  capacity=240 GB  capacity=250 GB  capacity=256 GB  \
# 0           False            False            False            False
# 1           False            False            False            False
# 2           False            False            False            False
# 3           False            False            False            False
# 4           False            False            False            False
#
#    capacity=275 GB  capacity=280 GB  capacity=32 GB  capacity=360 GB  \
# 0            False            False           False            False
# 1            False            False           False            False
# 2            False            False           False            False
# 3            False            False           False            False
# 4            False            False           False            False
#
#    capacity=380 GB  capacity=4 GB  capacity=400 GB  capacity=4000 GB  \
# 0            False          False            False             False
# 1            False          False            False             False
# 2            False          False            False             False
# 3            False          False            False             False
# 4            False          False            False             False
#
#    capacity=48 GB  capacity=480 GB  capacity=500 GB  capacity=512 GB  \
# 0           False            False            False            False
# 1           False            False            False            False
# 2           False            False            False            False
# 3           False            False            False            False
# 4           False            False            False            False
#
#    capacity=525 GB  capacity=58 GB  capacity=60 GB  capacity=64 GB  \
# 0            False           False           False           False
# 1            False           False           False           False
# 2            False           False           False           False
# 3            False           False           False           False
# 4            False           False           False           False
#
#    capacity=8 GB  capacity=800 GB  capacity=8000 GB  capacity=96 GB  \
# 0          False            False             False           False
# 1          False            False             False           False
# 2          False            False             False           False
# 3          False            False             False           False
# 4          False            False             False           False
#
#    capacity=960 GB  capacity=ATX  capacity=ATX PS/2  capacity=ATX, SFX  \
# 0            False         False              False              False
# 1            False         False              False              False
# 2            False         False              False              False
# 3            False         False              False              False
# 4            False         False              False              False
#
#    capacity=ATX, SFX-L  capacity=Flex-ATX  capacity=ITX  capacity=SFX  \
# 0                False              False         False         False
# 1                False              False         False         False
# 2                False              False         False         False
# 3                False              False         False         False
# 4                False              False         False         False
#
#    capacity=SFX-L  capacity=TFX  capacity=Unknown  capacity=extern, sonstige  \
# 0           False         False              True                      False
# 1           False         False              True                      False
# 2           False         False              True                      False
# 3           False         False              True                      False
# 4           False         False              True                      False
#
#    capacity=external  capacity=misc  capacity=redundant  \
# 0              False          False               False
# 1              False          False               False
# 2              False          False               False
# 3              False          False               False
# 4              False          False               False
#
#    capacity=redundantes Netzteil  capacity=sonstige  chipset=760G  \
# 0                          False              False         False
# 1                          False              False         False
# 2                          False              False         False
# 3                          False              False         False
# 4                          False              False         False
#
#    chipset=970  chipset=970/SB950  chipset=990FX  chipset=990X  chipset=A320  \
# 0        False              False          False         False         False
# 1        False              False          False         False         False
# 2        False              False          False         False         False
# 3        False              False          False         False         False
# 4        False              False          False         False         False
#
#    chipset=A50  chipset=A520  chipset=A58  chipset=A68H  \
# 0        False         False        False         False
# 1        False         False        False         False
# 2        False         False        False         False
# 3        False         False        False         False
# 4        False         False        False         False
#
#    chipset=A68H FCH (Bolton D2H)  chipset=A88X  chipset=A88X (Bolton D4)  \
# 0                          False         False                     False
# 1                          False         False                     False
# 2                          False         False                     False
# 3                          False         False                     False
# 4                          False         False                     False
#
#    chipset=B150  chipset=B250  chipset=B350  chipset=B360  chipset=B365  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    chipset=B450  chipset=B460  chipset=B550  chipset=B560  chipset=B650  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    chipset=B650E  chipset=B660  chipset=B760  chipset=B85  chipset=C222  \
# 0          False         False         False        False         False
# 1          False         False         False        False         False
# 2          False         False         False        False         False
# 3          False         False         False        False         False
# 4          False         False         False        False         False
#
#    chipset=C232  chipset=C236  chipset=C246  chipset=C612  chipset=C612 PCH  \
# 0         False         False         False         False             False
# 1         False         False         False         False             False
# 2         False         False         False         False             False
# 3         False         False         False         False             False
# 4         False         False         False         False             False
#
#    chipset=G41 Express  chipset=H110  chipset=H170  chipset=H270  \
# 0                False         False         False         False
# 1                False         False         False         False
# 2                False         False         False         False
# 3                False         False         False         False
# 4                False         False         False         False
#
#    chipset=H310  chipset=H370  chipset=H410  chipset=H470  chipset=H510  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    chipset=H570  chipset=H61  chipset=H610  chipset=H670  chipset=H770  \
# 0         False        False         False         False         False
# 1         False        False         False         False         False
# 2         False        False         False         False         False
# 3         False        False         False         False         False
# 4         False        False         False         False         False
#
#    chipset=H81  chipset=H97  chipset=Kabini (integriert)  chipset=Q170  \
# 0        False        False                        False         False
# 1        False        False                        False         False
# 2        False        False                        False         False
# 3        False        False                        False         False
# 4        False        False                        False         False
#
#    chipset=Q270  chipset=Q87  chipset=SoC  chipset=TRX40  chipset=Unknown  \
# 0         False        False        False          False             True
# 1         False        False        False          False             True
# 2         False        False        False          False             True
# 3         False        False        False          False             True
# 4         False        False        False          False             True
#
#    chipset=W480  chipset=WRX80  chipset=X299  chipset=X370  chipset=X399  \
# 0         False          False         False         False         False
# 1         False          False         False         False         False
# 2         False          False         False         False         False
# 3         False          False         False         False         False
# 4         False          False         False         False         False
#
#    chipset=X470  chipset=X570  chipset=X570S  chipset=X670  chipset=X670E  \
# 0         False         False          False         False          False
# 1         False         False          False         False          False
# 2         False         False          False         False          False
# 3         False         False          False         False          False
# 4         False         False          False         False          False
#
#    chipset=X99  chipset=X99 Express  chipset=Z170  chipset=Z270  chipset=Z370  \
# 0        False                False         False         False         False
# 1        False                False         False         False         False
# 2        False                False         False         False         False
# 3        False                False         False         False         False
# 4        False                False         False         False         False
#
#    chipset=Z390  chipset=Z490  chipset=Z590  chipset=Z690  chipset=Z790  \
# 0         False         False         False         False         False
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    chipset=Z87  chipset=Z97  component_type=CPU  component_type=GPU  \
# 0        False        False                True               False
# 1        False        False                True               False
# 2        False        False                True               False
# 3        False        False                True               False
# 4        False        False                True               False
#
#    component_type=Motherboard  component_type=PSU  component_type=RAM  \
# 0                       False               False               False
# 1                       False               False               False
# 2                       False               False               False
# 3                       False               False               False
# 4                       False               False               False
#
#    component_type=Storage  efficiency=80 PLUS  efficiency=80 PLUS Bronze  \
# 0                   False               False                      False
# 1                   False               False                      False
# 2                   False               False                      False
# 3                   False               False                      False
# 4                   False               False                      False
#
#    efficiency=80 PLUS Gold  efficiency=80 PLUS Platinum  \
# 0                    False                        False
# 1                    False                        False
# 2                    False                        False
# 3                    False                        False
# 4                    False                        False
#
#    efficiency=80 PLUS Silver  efficiency=80 PLUS Titanium  efficiency=80 Plus  \
# 0                      False                        False               False
# 1                      False                        False               False
# 2                      False                        False               False
# 3                      False                        False               False
# 4                      False                        False               False
#
#    efficiency=80 Plus Bronze  efficiency=80 Plus Gold  \
# 0                      False                    False
# 1                      False                    False
# 2                      False                    False
# 3                      False                    False
# 4                      False                    False
#
#    efficiency=80 Plus Platinum  efficiency=80 Plus Silver  \
# 0                        False                      False
# 1                        False                      False
# 2                        False                      False
# 3                        False                      False
# 4                        False                      False
#
#    efficiency=80 Plus Titanium  efficiency=Unknown  form_factor=ATX  \
# 0                        False                True            False
# 1                        False                True            False
# 2                        False                True            False
# 3                        False                True            False
# 4                        False                True            False
#
#    form_factor=CEB  form_factor=E-ATX  form_factor=EEB  form_factor=ITX  \
# 0            False              False            False            False
# 1            False              False            False            False
# 2            False              False            False            False
# 3            False              False            False            False
# 4            False              False            False            False
#
#    form_factor=M.2  form_factor=Micro-ATX  form_factor=Mini-DTX  \
# 0            False                  False                 False
# 1            False                  False                 False
# 2            False                  False                 False
# 3            False                  False                 False
# 4            False                  False                 False
#
#    form_factor=Mini-ITX  form_factor=Mini-STX  form_factor=SATA  \
# 0                 False                 False             False
# 1                 False                 False             False
# 2                 False                 False             False
# 3                 False                 False             False
# 4                 False                 False             False
#
#    form_factor=SSI  form_factor=Thin-Mini-ITX  form_factor=Unknown  \
# 0            False                      False                 True
# 1            False                      False                 True
# 2            False                      False                 True
# 3            False                      False                 True
# 4            False                      False                 True
#
#    form_factor=XL-ATX  form_factor=XL-ATX, CEB  memory_type=DDR3  \
# 0               False                    False             False
# 1               False                    False             False
# 2               False                    False             False
# 3               False                    False             False
# 4               False                    False             False
#
#    memory_type=DDR4  memory_type=DDR4, ECC - Speicher  \
# 0             False                             False
# 1             False                             False
# 2             False                             False
# 3             False                             False
# 4             False                             False
#
#    memory_type=DDR4, SO - DIMM  memory_type=DDR5  memory_type=SO - DIMM  \
# 0                        False             False                  False
# 1                        False             False                  False
# 2                        False             False                  False
# 3                        False             False                  False
# 4                        False             False                  False
#
#    memory_type=Unknown  ram_type=DDR1-333  ram_type=DDR1-400  \
# 0                 True              False              False
# 1                 True              False              False
# 2                 True              False              False
# 3                 True              False              False
# 4                 True              False              False
#
#    ram_type=DDR2-533  ram_type=DDR2-667  ram_type=DDR2-800  \
# 0              False              False              False
# 1              False              False              False
# 2              False              False              False
# 3              False              False              False
# 4              False              False              False
#
#    ram_type=DDR3-1066  ram_type=DDR3-1333  ram_type=DDR3-1600  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR3-1866  ram_type=DDR3-2000  ram_type=DDR3-2133  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR3-2400  ram_type=DDR3-2666  ram_type=DDR3-2800  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR3-2933  ram_type=DDR3-3000  ram_type=DDR3L-1600  \
# 0               False               False                False
# 1               False               False                False
# 2               False               False                False
# 3               False               False                False
# 4               False               False                False
#
#    ram_type=DDR3L-1866  ram_type=DDR3L-2133  ram_type=DDR4-2133  \
# 0                False                False               False
# 1                False                False               False
# 2                False                False               False
# 3                False                False               False
# 4                False                False               False
#
#    ram_type=DDR4-2400  ram_type=DDR4-2666  ram_type=DDR4-2800  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR4-2933  ram_type=DDR4-3000  ram_type=DDR4-3200  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR4-3300  ram_type=DDR4-3333  ram_type=DDR4-3400  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR4-3466  ram_type=DDR4-3600  ram_type=DDR4-3733  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR4-3866  ram_type=DDR4-4000  ram_type=DDR4-4133  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR4-4200  ram_type=DDR4-4266  ram_type=DDR4-4400  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR4-4500  ram_type=DDR4-4600  ram_type=DDR4-4800  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR4-5000  ram_type=DDR5-4800  ram_type=DDR5-5200  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR5-5600  ram_type=DDR5-6000  ram_type=DDR5-6200  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR5-6400  ram_type=DDR5-6600  ram_type=DDR5-6800  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR5-7000  ram_type=DDR5-7200  ram_type=DDR5-7800  \
# 0               False               False               False
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
# 4               False               False               False
#
#    ram_type=DDR5-8000  ram_type=Unknown  socket=1150  socket=1151  \
# 0               False              True        False        False
# 1               False              True        False        False
# 2               False              True        False        False
# 3               False              True        False        False
# 4               False              True        False        False
#
#    socket=1155  socket=1200  socket=1700  socket=2011-3  socket=2011-V3  \
# 0        False        False        False          False           False
# 1        False        False        False          False           False
# 2        False        False        False          False           False
# 3        False        False        False          False           False
# 4        False        False        False          False           False
#
#    socket=2011-v3  socket=2066  socket=775  socket=AM1  socket=AM3  \
# 0           False        False       False       False       False
# 1           False        False       False       False       False
# 2           False        False       False       False       False
# 3           False        False       False       False       False
# 4           False        False       False       False       False
#
#    socket=AM3+  socket=AM3, AM3+  socket=AM4  socket=AM5  socket=FM2  \
# 0        False             False        True       False       False
# 1        False             False        True       False       False
# 2        False             False        True       False       False
# 3        False             False        True       False       False
# 4        False             False        True       False       False
#
#    socket=FM2+  socket=FM2, FM2+  socket=SoC  socket=TR4  socket=TRX40  \
# 0        False             False       False       False         False
# 1        False             False       False       False         False
# 2        False             False       False       False         False
# 3        False             False       False       False         False
# 4        False             False       False       False         False
#
#    socket=Unknown  socket=sWRX8  socket=sWRX80  vram=0.7 GB  vram=1 GB  \
# 0           False         False          False        False      False
# 1           False         False          False        False      False
# 2           False         False          False        False      False
# 3           False         False          False        False      False
# 4           False         False          False        False      False
#
#    vram=1.2 GB  vram=1.5 GB  vram=10 GB  vram=11 GB  vram=12 GB  vram=16 GB  \
# 0        False        False       False       False       False       False
# 1        False        False       False       False       False       False
# 2        False        False       False       False       False       False
# 3        False        False       False       False       False       False
# 4        False        False       False       False       False       False
#
#    vram=2 GB  vram=20 GB  vram=24 GB  vram=3 GB  vram=3.5 GB  vram=4 GB  \
# 0      False       False       False      False        False      False
# 1      False       False       False      False        False      False
# 2      False       False       False      False        False      False
# 3      False       False       False      False        False      False
# 4      False       False       False      False        False      False
#
#    vram=6 GB  vram=8 GB  vram=Unknown  wattage=1000 W  wattage=1050 W  \
# 0      False      False          True           False           False
# 1      False      False          True           False           False
# 2      False      False          True           False           False
# 3      False      False          True           False           False
# 4      False      False          True           False           False
#
#    wattage=1100 W  wattage=120 W  wattage=1200 W  wattage=1250 W  \
# 0           False          False           False           False
# 1           False          False           False           False
# 2           False          False           False           False
# 3           False          False           False           False
# 4           False          False           False           False
#
#    wattage=1300 W  wattage=1350 W  wattage=1450 W  wattage=150 W  \
# 0           False           False           False          False
# 1           False           False           False          False
# 2           False           False           False          False
# 3           False           False           False          False
# 4           False           False           False          False
#
#    wattage=1500 W  wattage=160 W  wattage=1600 W  wattage=1650 W  \
# 0           False          False           False           False
# 1           False          False           False           False
# 2           False          False           False           False
# 3           False          False           False           False
# 4           False          False           False           False
#
#    wattage=1700 W  wattage=180 W  wattage=2000 W  wattage=240 W  \
# 0           False          False           False          False
# 1           False          False           False          False
# 2           False          False           False          False
# 3           False          False           False          False
# 4           False          False           False          False
#
#    wattage=250 W  wattage=300 W  wattage=320 W  wattage=350 W  wattage=360 W  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
# 4          False          False          False          False          False
#
#    wattage=400 W  wattage=430 W  wattage=450 W  wattage=460 W  wattage=500 W  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
# 4          False          False          False          False          False
#
#    wattage=520 W  wattage=530 W  wattage=550 W  wattage=560 W  wattage=600 W  \
# 0          False          False          False          False          False
# 1          False          False          False          False          False
# 2          False          False          False          False          False
# 3          False          False          False          False          False
# 4          False          False          False          False          False
#
#    wattage=620 W  wattage=630 W  wattage=65 W  wattage=650 W  wattage=660 W  \
# 0          False          False         False          False          False
# 1          False          False         False          False          False
# 2          False          False         False          False          False
# 3          False          False         False          False          False
# 4          False          False         False          False          False
#
#    wattage=700 W  wattage=730 W  wattage=750 W  wattage=760 W  wattage=80 W  \
# 0          False          False          False          False         False
# 1          False          False          False          False         False
# 2          False          False          False          False         False
# 3          False          False          False          False         False
# 4          False          False          False          False         False
#
#    wattage=800 W  wattage=830 W  wattage=84 W  wattage=85 W  wattage=850 W  \
# 0          False          False         False         False          False
# 1          False          False         False         False          False
# 2          False          False         False         False          False
# 3          False          False         False         False          False
# 4          False          False         False         False          False
#
#    wattage=860 W  wattage=90 W  wattage=900 W  wattage=Unknown
# 0          False         False          False             True
# 1          False         False          False             True
# 2          False         False          False             True
# 3          False         False          False             True
# 4          False         False          False             True

# %%
num_transactions = encoded_df.shape[0]
num_items = encoded_df.shape[1]

sparsity = 1 - (encoded_df.values.sum() / (num_transactions * num_items))

print(f"Transactions: {num_transactions}")
print(f"Unique Items: {num_items}")
print(f"Sparsity: {sparsity:.4f}")
# Out:
# Transactions: 6357
# Unique Items: 407
# Sparsity: 0.9730

# %%
min_support_threshold = 0.02  # 2%

item_support = encoded_df.mean()
frequent_items = item_support[item_support >= min_support_threshold].index

filtered_df = encoded_df[frequent_items]

print(f"Items before filtering: {encoded_df.shape[1]}")
print(f"Items after filtering: {filtered_df.shape[1]}")
# Out:
# Items before filtering: 407
# Items after filtering: 52

# %%
filtered_df.to_csv("processed_pc_hardware_transactions.csv", index=False)

# %%
from google.colab import files
files.download("processed_pc_hardware_transactions.csv")
